# %%
"""
연습 사이트: https://quotes.toscrape.com
"""

from selenium import webdriver
from selenium.webdriver.common.by import By


# -------------------------------------------------
# 공통: 드라이버 실행 및 1페이지 접속
# -------------------------------------------------
driver = webdriver.Chrome()
driver.get("https://quotes.toscrape.com")


# =================================================
# 문제 1 (기초)
# =================================================
"""
[문제 1]
1페이지에서 모든 명언(text)과 저자(author)를 출력하세요.

출력 형식:
명언 - 저자

조건:
- find_elements()를 사용하세요.
- 각 quote 블록 안에서 다시 요소를 찾으세요.
"""
print("\n===== 정답 1 - 1페이지 : 명언 + 저자 출력 =====")
quote_blocks = driver.find_elements(By.CLASS_NAME, 'quote')

for block in quote_blocks:
    quote_text = block.find_element(By.CLASS_NAME, 'text').text
    author = block.find_element(By.CLASS_NAME, 'author').text
    print(quote_text, '-', author)


# =================================================
# 문제 2 (중급)
# =================================================
"""
[문제 2]
1페이지에서 각 명언의 태그 개수를 함께 출력하세요.

출력 형식 예:
명언 - 저자 (태그 3개)

조건:
- 태그는 class="tag" 입니다.
- 태그는 여러 개일 수 있습니다.
- len()을 활용하세요.
"""
print("\n===== 정답 2 - 1페이지 : 태그 개수까지 출력 =====")
quote_blocks = driver.find_elements(By.CLASS_NAME, 'quote')

for block in quote_blocks:
    quote_text = block.find_element(By.CLASS_NAME, 'text').text
    author = block.find_element(By.CLASS_NAME, 'author').text
    tag_elements = block.find_elements(By.CLASS_NAME, 'tag')
    print(f"{quote_text} - {author} (태그 : {len(tag_elements)})")


# =================================================
# 문제 3 (중상)
# =================================================
"""
[문제 3]
2페이지까지 이동하여 총 몇 개의 명언을 수집했는지 출력하세요.

조건:
- Next 버튼을 클릭하세요.
- 반복문을 사용하세요.
- 페이지 이동 후 다시 요소를 수집하세요.
"""
print("\n===== 정답 3 - 2페이지까지 수집 후 총 개수 출력 =====")
total_quotes = 0
current_page = 1
MAX_PAGES = 2

while current_page <= MAX_PAGES:
    quote_blocks = driver.find_elements(By.CLASS_NAME,'quote')
    total_quotes += len(quote_blocks)
    
    # 2페이지까지니까, 1페이지에서만 Next를 누르면 됨
    if current_page < MAX_PAGES:
        next_buttons = driver.find_elements(By.CSS_SELECTOR, 'li.next a')
        if not next_buttons:
            break
        next_buttons[0].click()

    current_page += 1

print("2페이지까지 총 명언 개수 :", total_quotes)


# =================================================
# 문제 4 (활용)
# =================================================
"""
[문제 4]
3페이지까지 수집하면서, 태그에 "love"가 포함된 명언만 출력하세요.

출력 형식:
[LOVE] 명언 - 저자

조건:
- 태그 목록(tags) 안에 "love"가 있으면 출력합니다.
"""
print("\n===== 정답 4 - 3페이지까지 : love 태그가 있는 명언만 출력 =====")
driver.get('https://quotes.toscrape.com')

current_page = 1
MAX_PAGES = 3

while current_page <= MAX_PAGES:
    quote_blocks = driver.find_elements(By.CLASS_NAME, 'quote')

    for block in quote_blocks:
        quote_text = block.find_element(By.CLASS_NAME, 'text').text
        author = block.find_element(By.CLASS_NAME, 'author').text
        tag_elements = block.find_elements(By.CLASS_NAME, 'tag')
        tags = [t.text for t in tag_elements]

        if 'love' in tags:
            print(f"[LOVE] {quote_text} - {author}")

    if current_page < MAX_PAGES:
        next_buttons = driver.find_elements(By.CSS_SELECTOR, 'li.next a')
        if not next_buttons:
            break
        next_buttons[0].click()

    current_page += 1


# =================================================
# 문제 5 (도전)
# =================================================
"""
[문제 5]
3페이지까지 수집한 뒤, 저자별로 명언이 몇 개 있는지 출력하세요.

출력 예:
Albert Einstein : 2개
Mark Twain : 3개

조건:
- 딕셔너리를 사용하세요.
- key = author, value = 개수
"""
print("\n===== 정답5 - 3페이지까지 : 저자별 명언 개수 집계 =====")
driver.get('https://quotes.toscrape.com')

author_count = {}
current_page = 1
MAX_PAGES = 3

while current_page <= MAX_PAGES:
    quote_blocks = driver.find_elements(By.CLASS_NAME, 'quote')

    for block in quote_blocks:
        author = block.find_element(By.CLASS_NAME, 'author').text

        # 딕셔너리 집계 패턴
        # author가 없으면 0에서 시작해서 1씩 증가
        author_count[author] = author_count.get(author, 0) + 1

    if current_page < MAX_PAGES:
        next_buttons = driver.find_elements(By.CSS_SELECTOR, 'li.next a')
        if not next_buttons:
            break
        next_buttons[0].click()

    current_page += 1

for author, count in author_count.items():
    print(f"{author} : {count}개")

# -------------------------------------------------
# 브라우저 종료
# -------------------------------------------------
driver.quit()
# Out:
# ===== 정답 1 - 1페이지 : 명언 + 저자 출력 =====
# “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.” - Albert Einstein
# “It is our choices, Harry, that show what we truly are, far more than our abilities.” - J.K. Rowling
# “There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.” - Albert Einstein
# “The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.” - Jane Austen
# “Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.” - Marilyn Monroe
# “Try not to become a man of success. Rather become a man of value.” - Albert Einstein
# “It is better to be hated for what you are than to be loved for what you are not.” - André Gide
# “I have not failed. I've just found 10,000 ways that won't work.” - Thomas A. Edison
# “A woman is like a tea bag; you never know how strong it is until it's in hot water.” - Eleanor Roosevelt
# “A day without sunshine is like, you know, night.” - Steve Martin
#
# ===== 정답 2 - 1페이지 : 태그 개수까지 출력 =====
# “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.” - Albert Einstein (태그 : 4)
# “It is our choices, Harry, that show what we truly are, far more than our abilities.” - J.K. Rowling (태그 : 2)
# “There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.” - Albert Einstein (태그 : 5)
# “The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.” - Jane Austen (태그 : 4)
# “Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.” - Marilyn Monroe (태그 : 2)
# “Try not to become a man of success. Rather become a man of value.” - Albert Einstein (태그 : 3)
# “It is better to be hated for what you are than to be loved for what you are not.” - André Gide (태그 : 2)
# “I have not failed. I've just found 10,000 ways that won't work.” - Thomas A. Edison (태그 : 4)
# “A woman is like a tea bag; you never know how strong it is until it's in hot water.” - Eleanor Roosevelt (태그 : 1)
# “A day without sunshine is like, you know, night.” - Steve Martin (태그 : 3)
#
# ===== 정답 3 - 2페이지까지 수집 후 총 개수 출력 =====
# 2페이지까지 총 명언 개수 : 20
#
# ===== 정답 4 - 3페이지까지 : love 태그가 있는 명언만 출력 =====
# [LOVE] “It is better to be hated for what you are than to be loved for what you are not.” - André Gide
# [LOVE] “This life is what you make it. No matter what, you're going to mess up sometimes, it's a universal truth. But the good part is you get to decide how you're going to mess it up. Girls will be your friends - they'll act like it anyway. But just remember, some come, some go. The ones that stay with you through everything - they're your true best friends. Don't let go of them. Also remember, sisters make the best friends in the world. As for lovers, well, they'll come and go too. And baby, I hate to say it, most of them - actually pretty much all of them are going to break your heart, but you can't give up because if you give up, you'll never find your soulmate. You'll never find that half who makes you whole and that goes for everything. Just because you fail once, doesn't mean you're gonna fail at everything. Keep trying, hold on, and always, always, always believe in yourself, because if you don't, then who will, sweetie? So keep your head high, keep your chin up, and most importantly, keep smiling, because life's a beautiful thing and there's so much to smile about.” - Marilyn Monroe
# [LOVE] “You may not be her first, her last, or her only. She loved before she may love again. But if she loves you now, what else matters? She's not perfect—you aren't either, and the two of you may never be perfect together but if she can make you laugh, cause you to think twice, and admit to being human and making mistakes, hold onto her and give her the most you can. She may not be thinking about you every second of the day, but she will give you a part of her that she knows you can break—her heart. So don't hurt her, don't change her, don't analyze and don't expect more than she can give. Smile when she makes you happy, let her know when she makes you mad, and miss her when she's not there.” - Bob Marley
# [LOVE] “The opposite of love is not hate, it's indifference. The opposite of art is not ugliness, it's indifference. The opposite of faith is not heresy, it's indifference. And the opposite of life is not death, it's indifference.” - Elie Wiesel
# [LOVE] “It is not a lack of love, but a lack of friendship that makes unhappy marriages.” - Friedrich Nietzsche
# [LOVE] “I love you without knowing how, or when, or from where. I love you simply, without problems or pride: I love you in this way because I do not know any other way of loving but this, in which there is no I or you, so intimate that your hand upon my chest is my hand, so intimate that when I fall asleep your eyes close.” - Pablo Neruda
#
# ===== 정답5 - 3페이지까지 : 저자별 명언 개수 집계 =====
# Albert Einstein : 6개
# J.K. Rowling : 3개
# Jane Austen : 1개
# Marilyn Monroe : 2개
# André Gide : 1개
# Thomas A. Edison : 1개
# Eleanor Roosevelt : 1개
# Steve Martin : 1개
# Bob Marley : 2개
# Dr. Seuss : 2개
# Douglas Adams : 1개
# Elie Wiesel : 1개
# Friedrich Nietzsche : 1개
# Mark Twain : 1개
# Allen Saunders : 1개
# Pablo Neruda : 1개
# Ralph Waldo Emerson : 1개
# Mother Teresa : 1개
# Garrison Keillor : 1개
# Jim Henson : 1개
