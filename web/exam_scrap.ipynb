# %%
# requests 모듈 => 웹 페이지를 요청하고 응답 데이터를 받을 수 있음
import requests as req
from bs4 import BeautifulSoup # BeautifulSoup => html 해석기

# 요청 시 오류 났을 때 아래 문구를 입력해주세요.
# User-Agent : 웹 요청을 보낼 때 프로그램이 아니라 브라우저처럼 보이게 하는 정보
request_headers = {'User-Agent': ('Mozilla/5.0 (Windows NT 10.0;Win64; x64)AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98Safari/537.36'), }

# request_headers를 뒤에 추가해주세요.
response = req.get('https://www.naver.com/', request_headers)
# print(response)

html_doc = """<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

# print(html_doc)

soup = BeautifulSoup(html_doc, 'html.parser')
# soup을 이용해서 html_doc 문자열 파싱, 그 내용을 soup 변수에 대입

a_list = soup.select('a')

print("=== a태그들 리스트 ===")
print(a_list)

print("=== a태그 리스트 중 첫 번째 ===")
print(a_list[0])

print("=== a태그 리스트 중 첫 번째 텍스트 ===")
print(a_list[0].text)

print("=== a태그 리스트 중 첫 번째 링크 ===")
print(a_list[0]['href']) # 속성을 선택할 땐 대괄호

print("=== a태그 리스트에 있는 텍스트 모두 출력 ===")
for a in a_list:
    print(a.text)

print("=== a태그 리스트에 있는 링크 모두 출력 ===")
for link in a_list:
    print(link['href'])
# Out:
# === a태그들 리스트 ===
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>, <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>, <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]
# === a태그 리스트 중 첫 번째 ===
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
# === a태그 리스트 중 첫 번째 텍스트 ===
# Elsie
# === a태그 리스트 중 첫 번째 링크 ===
# http://example.com/elsie
# === a태그 리스트에 있는 텍스트 모두 출력 ===
# Elsie
# Lacie
# Tillie
# === a태그 리스트에 있는 링크 모두 출력 ===
# http://example.com/elsie
# http://example.com/lacie
# http://example.com/tillie

# %%
'''
◎ html

# 부모 엘리먼트
  # 조상 엘리먼트
<div>
  # 자식 엘리먼트
  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
  <div>
     # 후손 엘리먼트
     <a class="sister" href="http://example.com/elsie" id="link2">Elsie</a>
  </div>  
</div>

◎ css
1. 태그 선택
a { color: red; }

2. 후손 선택
div a { color: red; }

3. 자식 선택
div > a { color: red; }

4. class 선택
.sister { color: red; }

5. id 선택
#link1 { color: red; }
'''

# %%
import requests as req
from bs4 import BeautifulSoup

response = req.get('https://news.naver.com/')
# print(response)
# print(response.text)

# html 문자열 파싱
soup = BeautifulSoup(response.text,'html.parser')

content = soup.select('.cnf_news_title')
print(content[0].text)

print("== class로 선택, 반복문으로 텍스트 출력 ==")
for c in content:
    print(c.text)


print("== 후손 선택자로 선택, 반복문으로 이미지 주소 출력 ==")
imgs = soup.select('.cnf_news_thumb img')
for img in imgs:
    print(img['data-src']) # print(img['src'])
# Out:
# Middle East response pushes Lee’s ratings past 60% for first time since July
# == class로 선택, 반복문으로 텍스트 출력 ==
# Middle East response pushes Lee’s ratings past 60% for first time since July
# [속보] 감사원 “서울시 ‘한강버스’ 법규 위반…운항 속도 느린데도 사업 강행”
# 트럼프 한국 파병요청에 신문들 "킬박스 위험"…경향 "받아들일 수 없다"
# “20대는 아반떼, 40대는 카니발, 60대는 포터”…당근중고차, 세대별 선호도 조사
# '컷오프' 반발 김영환 "특정인 정해놓고 면접…공관위 결정 기가막혀"
# [단독]삼성전자 상무도 적금 깨서 매수…직원들도 '영끌 투자'
# 트럼프, 호르무즈 中 협조 압박…“미중 정상회담 연기할수도”
# 트럼프, 호르무즈 협조 압박..."미중 정상회담 연기할 수도"
# [NPL 워치]① 국민은행, 나홀로 지표 반등…부실 털고 방어력 키웠다
# "지금 너무 싸, 사라" 리포트에 우르르…중동쇼크 뚫고 '삼전닉스' 쑥
# 호르무즈 봉쇄 직격탄 석화업계…현 상태면 3월말~4월 중순 셧다운
# 올 것이 왔다...내달 유류할증료 3배 이상 ‘폭등’
# [타파스] 조선일보 ‘재벌집 막내아들’과 사라진 500만 달러
# 컷오프 반발 김영환 "원칙·절차 파괴…공관위 결정 수용 못해"
# 이란전 승자는 은둔의 한국 사업가…조용히 돈 쓸어담았다
# 트럼프 "호르무즈 호위 연합 참여 7國에 요구…참여여부 기억할것"(종합)
# 트럼프 "호르무즈 호위 연합 참여, 7개국에 요구"
# SK하이닉스, 삼성전자 제쳤다…'입사하고 싶은 대기업' 첫 1위
# [단독] 삼성전자 TV·가전·디자인 수장들 中 상하이 집결
# [속보]서울 집값 상승률, 작년 9월 이후 최저치
# 전쟁 속 '역대급 잭팟' 터진 한국 기업?… 유조선 빌려주고 매일 7억 번다
# “돈 구걸하는 통합은 가라…충북은 자강(自强)한다”
# 경찰, ‘위안부 모욕’ 단체 대표 구속영장…아동학대 혐의까지 적용
# 감사원 "한강버스 속도 기준 미달…예정 운항시간 충족 어려워"
# 대학 턱걸이 합격 선물,  아버지가 주신 등산학교 동계반 [등산시렁]
# “다른 페이지 더 있다” 내란 전모 밝힐 두 번째 기회 [특검IN]
# ‘케데헌’ 아카데미 2관왕…주제가상 받으며 K팝 새 역사
# 李대통령 “42세 포기하지 않은 노경은… 대한민국도 전진할 것”
# 참전 요구 거세지는 트럼프 "파병 여부 기억하겠다"... 5개국에서 7개국으로 늘려
# 청해부대 2020년 호르무즈 해협에 들어갔었다? [트럼프 군함 요구 Q&A]
# '1%의 선택' 삼전 팔고 향했다…두산에너빌리티 주가는
# ‘모텔 연쇄살인’ 김소영, 피해남성 3명 더 있었다…1명 동일약물 검출
# 국힘 ‘혁신 공천’ 시작부터 역풍…현역 김영환·박형준 공개 반발
# “3월에 끊으면 30만 원 덜 낸다”…중동발 유가 충격, 항공권 ‘숨은 요금’ 먼저 뛰었다
# 다카이치 총리의 ‘일하고×5’ 발언 유감
# [속보] '케이팝 데몬 헌터스' 아카데미 주제가상까지···오스카 2관왕
# 이 대통령, ‘42세 투혼’ 노경은에 찬사…“끊임없는 도전, 국민에 희망”
# 석유 최고가격제 틈새 노린 1원 ‘꼼수’…벌써부터 부작용
# 일자리수 금융위기 수준…20·40대 직격탄
# '바이든-날리면' 중징계 이끈 법원 판단, 이번엔 달랐다
# 이완용은 ‘명필’이었을까?…당대의 눈으로 본 그 시대 역사
# 119신고에도 발견 못해 숨진 공무원 대동맥박리 소견
# 특사경 수사범위 확대…주가조작·미공개정보거래 더 빨리 잡는다
# "트럼프, 이번 주 호르무즈 호위 연합체 구성 발표"…中 압박도 병행
# 아카데미 울린 '한국어 판소리'…배우들 응원봉 흔들었다
# ‘5년 공백’ 이소라, “몸무게 100kg 찍었다”… 최근 모습 봤더니?
# 삼전·하닉 조정에도…"반도체 호황 지속, 이익전망치 상향"
# “불탄 집 새로 짓고 농사 준비 마쳤더니 빚만 수억원”
# 변호사 낀 85억 전세 대출 사기.. 5명 구속 송치
# 이란전 최대 승자 된 한국 해운사…빈 유조선 들고가 ‘하루 50만달러’ 싹쓸이
# 트럼프, 이번주 '호르무즈 해협 연합' 발표…한국 포함 촉각
# 경찰, '위안부' 피해자 모욕 단체 대표 사자명예훼손 등 혐의 구속영장
# 트럼프 “해협 연합 참여 7개국 요구”…“미중 회담 연기 가능”
# 오세훈 한강버스, 기준속도 미달 속였다…감사원 “규정 위반”
# "화가 나서 바로 취소했다" 넷플릭스 구독 해지하는 일본인들, 무슨일?
# ‘노조 식물화’ 실적 내세워 줄줄이 계약 따내는 태가비엠
# 트럼프 "7개국에 호르무즈 호위 요구…참여 여부 기억할 것"
# 5개국 아닌 7개국으로 늘었다? 트럼프 “호르무즈 해협 보호 위해 7개국에 군함 파견 요청”
# ‘최후의 카드’ 기뢰 부설로 호르무즈해협 봉쇄 나선 이란
# 트럼프의 군함 파견 요구에…中관영지 “불 질러 놓고 같이 끄자 하나”
# “결혼식 하객도 금속탐지 검사”… BTS 공연날 통제에 엇갈린 반응
# Palisade recall after fatal accident estimated to cost Hyundai Motor 100 billion won
# 한국 '콕' 집었던 트럼프 "호르무즈 호위 참여 여부 기억할 것"
# "피할 곳 없다" 이란발 쩐의 전쟁…월가 고수들 베팅한 '비밀 피난처' [GMC]
# 李대통령 "월수입 수백만 원이나 제로인 노인 기초연금액 똑같아…빈곤 노인에게 조금 후하게 지급해도 되지 않겠나"
# 트럼프 "호르무즈 해협 확보 비협조국 기억할 것"…中 겨냥?
# “너무 떨려” BTS 지민, 컴백 콘서트 준비 근황… 춤선 비결은 운동?
# "문 잠겨서 철수"… 119 신고 후 숨진 채 발견된 30대 공무원, 사인은 '대동맥박리'
# 암 '독가스'에 무너지던 면역세포, 방호복 입고 다시 싸운다
# 미국의 파병 요청, 곤혹스럽지만... 이렇게 답해야 한다
# 이 대통령 "42세 노경은에 깊은 인상...국민에게 희망과 투지 넣어"
# "자사주 소각에 DPS 상향까지"…기업들 배당 늘리는 진짜 이유
# "기초연금 감액 피하려고 위장이혼까지...노부부 불이익 없애야"...이재명, 기초연금 '차등 인상' 공론화
# 모즈타바, 부상으로 치료차 러시아로... 이란 지도부 공백 가능성
# “4.5억 더 내고 이사 안갈래요” 서초 전세 재계약 70%인데 갱신권 안써 [부동산360]
# 연임은 까다롭게, 성과급은 엄격하게…금융지주 지배구조 개편 초읽기
# 호르무즈 막히자 '잭팟' 터진 한국 회사…"이번 혼란의 최대 수혜자"
# 국민의힘 공관위, '박형준 컷오프'검토에 발칵
# 호르무즈 호위 연합 발표에…전투함 파견 딜레마 빠진 한국
